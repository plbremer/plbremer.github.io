# %% [markdown]
# # Brief concept-introduction to understand <a href="http://folding.cnsm.csulb.edu/pubs/Bremer_Non-Heuristic-MD-Clustering_JCIM2020.pdf">this paper</a>

# %% [markdown]
# ## Background on Molecular Dynamics (MD)

# %% [markdown]
# <a href="https://www.youtube.com/watch?v=veBZYlD6AF4">This youtube video</a> offers a succinct summary of MD for people who have some experience with classical mechanics and (bio)chemistry

# %% [markdown]
# ## Background on Protein-Ligand Interactions

# %% [markdown]
# ### Small Molecules can Interact with Certain Parts of Certain Proteins

# %% [markdown]
# One approach for drug development is to find small (molar mass ~<1000 grams/mol) molecules that interact with special areas (binding sites) on proteins. These binding sites normally conduct the chemistry that is the function of the protein. By finding molecules that interact with these binding sites, the proteins are too occupied to perform chemistry on normal biomolecules.

# %% [markdown]
# ![protein_ligand_pocket.png](attachment:protein_ligand_pocket.png)

# %% [markdown]
# Figure: A protiein (grey) and its binding pocket (colored blobs) interact with a small molecule (cyan, white, orange, and red stick)

# %% [markdown]
# ### Molecular Dynamics Produces a Set of Structures At Different Times

# %% [markdown]
# As expressed in the youtube video, MD gives a snapshot of a system at different time intervals. If we line up these images, they might look something like

# %% [markdown]
# ![Picture1.png](attachment:Picture1.png)

# %% [markdown]
# ### The over-time ensemble averages to the same thing as an in vitro ensemble

# %% [markdown]
# If we were to track a single molecule of air for sufficiently long, then we would expect it to exhibit, proportionally, all of the speeds exhibited by many air molecules according to the Boltzmann distribution. Likewise, if we track a single protein-ligand system for a sufficiently long time, we observe the same as if we were to examine many of these protein-ligand systems at the same time in a simple experiment that took place in a beaker.

# %% [markdown]
# ![Picture5.PNG](attachment:Picture5.PNG)

# %% [markdown]
# ### The drug-protein interaction is not static, instead there are multiple "poses" between which the drug and binding pocket oscillate

# %% [markdown]
# Suppose that this drug system had two potential poses seen below. With many individuals, as you would have in your body or in a beaker experiement or in a long-time MD sampling, the many inidividuals would partition themselves between the two poses. The ratio of the partition would depend on the relative potential energies - poses with higher potentials have smaller populations.

# %% [markdown]
# ![pose1.png](attachment:pose1.png)

# %% [markdown]
# ![pose2.png](attachment:pose2.png)

# %% [markdown]
# ### In this paper, we showcase an approach to ascertain and succinctly represent these poses

# %% [markdown]
# The motivation for this is open-ended, but one potential use is to offer a method to systems where detailed study of protein-ligand interaction is desired.  Rationale drug design can incorporate the set of poses that can be ascertained through this method.
